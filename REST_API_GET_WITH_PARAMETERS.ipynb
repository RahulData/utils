# %% [markdown]
# ### https://www.dataquest.io/blog/python-api-tutorial/

# %%
import requests

# %%
parameters = {
    "requestId": 7,
    "dataDropId": 17
}

# %%
response = requests.get("https://vcgbackendprocessapi.azurewebsites.net/api/VCGProcess/GetMetadata", params=parameters)

# %%
print(response.status_code)
# Out:
# 200

# %%
response.json()
# Out:
# [{'bodyTypeCode': '4D',
#   'createdBy': 'API',
#   'creationDate': '2019-10-10T05:36:33.67',
#   'dailyDataDropId': 17,
#   'id': 1,
#   'isProcessed': False,
#   'isReceived': True,
#   'requestId': 7,
#   'stockNumber': '25993355',
#   'updatedBy': 'API',
#   'updatedDate': '2019-10-10T05:36:33.67',
#   'url01': 'https://linkprotect.cudasvc.com/url?a=http%3a%2f%2fvis.iaai.com%2fresizer%3fimagekeys%3d25993355~I1%5cu0026Width%3d640%5cu0026Height%3d480&c=E,1,C7__AygM2P8qE6UggFl1oLEP0CyHFZwBpWHd0hqq1bpUzMVWrFaM0jEB94RWe5ih-GfhmhaBbjv4hpAvneY-nC2HM7sNvRl0Z9yNngcdtbrTQ6g,&typo=1',
#   'url02': 'https://linkprotect.cudasvc.com/url?a=http%3a%2f%2fvis.iaai.com%2fresizer%3fimagekeys%3d25993355~I2%5cu0026Width%3d640%5cu0026Height%3d480&c=E,1,lF2hQpKX3sGbryIUubbZ0PbU0pjg0iZVottUMeFIN3uGAdFJNkbVRGk1KBwhkTcQXC_u1bdS_KTdVKGZAyR_mMKdkPASVD6l1Ca5Y5N5Vw,,&typo=1',
# ...

# %%
len(response.json())
# Out:
# 20

# %%
type(response.json())
# Out:
# list

# %%
resp_list = response.json()

stocks = [ i['stockNumber'] for i in resp_list]

# %%
stocks
# Out:
# ['25993355',
#  '25996375',
#  '25999969',
#  '26006820',
#  '26007258',
#  '26007817',
#  '26010851',
#  '26011855',
#  '26013674',
#  '26015608',
#  '26015678',
#  '26018246',
#  '26019059',
#  '26023222',
#  '25952505',
#  '25997809',
#  '26014019',
#  '25988056',
#  '26015438',
#  '25978554']

# %%
len(stocks)
# Out:
# 20
